# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/Earners_AI_ML_Lec_1_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Earners AIML by Aditya Jain Sir - Lecture->1.10

# %% [markdown]
# #Recap

# %%
for i in range(5):
  for j in range(6,10):
    print(i,j)
# Out:
# 0 6
# 0 7
# 0 8
# 0 9
# 1 6
# 1 7
# 1 8
# 1 9
# 2 6
# 2 7
# 2 8
# 2 9
# 3 6
# 3 7
# 3 8
# 3 9
# 4 6
# 4 7
# 4 8
# 4 9

# %%
for i in range(2):
  for j in range(2):
    print(j,end =" ")
  print()
# Out:
# 0 1
# 0 1

# %%
for row in range(4):
  for col in range(4):
    print('#', end =" ")
  print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
  for i in range(1,3):
   for j in range(1,3):
     print(i,j,i+j)
   print()
# Out:
# 1 1 2
# 1 2 3
#
# 2 1 3
# 2 2 4

# %% [markdown]
# #List

# %%
m1 = 90
m2 = 86
m3 = 95
m4 = 83
m5 = 70
marks=[m1,m2,m3,m4,m5]
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
a=[45,'aj',6.9,True]
print(a)
# Out:
# [45, 'aj', 6.9, True]

# %%
type(a)
# Out:
# list

# %%
type(marks)
# Out:
# list

# %% [markdown]
# #Indexing

# %%
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[0]
# Out:
# 90

# %%
marks[2]
# Out:
# 95

# %%
n=len(marks)
print(n)
# Out:
# 5

# %%
marks[n-2]
# Out:
# 83

# %%
marks[n-1]
# Out:
# 70

# %%
marks[-1]
# Out:
# 70

# %%
marks[-2]
# Out:
# 83

# %%
# marks[5]#index error

# %%
marks[2]+=2
print(marks[2])
# Out:
# 97

# %%
marks[2]=97
print(marks)
# Out:
# [90, 86, 97, 83, 70]

# %% [markdown]
# #Iterating over a list

# %%
n=len(marks)
print(n)
# Out:
# 5

# %%
marks[0]
# Out:
# 90

# %%
marks[1]
# Out:
# 86

# %%
for elem in range(n):
  print(marks[elem])
# Out:
# 90
# 86
# 97
# 83
# 70

# %%
for elem in marks:
  print(elem)
# Out:
# 90
# 86
# 97
# 83
# 70

# %%
#print elem at even index
for i in range(0,n,2):
  print(marks[i])
# Out:
# 90
# 97
# 70

# %%
#m2
for i in range(n):
  if i%2==0:
    print(marks[i])
# Out:
# 90
# 97
# 70

# %%
#print all even elements
for i in range(n):
  if marks[i]%2==0:
    print(marks[i])
# Out:
# 90
# 86
# 70

# %%
print(max(marks))
# Out:
# 97

# %%
print(min(marks))
# Out:
# 70

# %%
#write a code to find the sum of all elem of list.
marks=[60,70,80,90]
sm=0
for elem in marks:
  sm =sm+elem
print(sm)
# Out:
# 300

# %%
#sum(marks)

# %%
# find average of marks
avg=(marks[0]+marks[1]+marks[2]+marks[3])/4
print(avg)
# Out:
# 75.0

# %%
#avg
n=len(marks)
sm=0
for elem in marks:
  sm=sm+elem
print(sm/n)
# Out:
# 75.0

# %%
numbers=[9,5,7,1]
print(sorted(numbers))
# Out:
# [1, 5, 7, 9]

# %%
numbers.sort()
# Out:
# 1

# %%
print(numbers)
# Out:
# [1, 5, 7, 9]

# %%
names=["a","b","c"]
print(names[len(names)-1])
# Out:
# c

# %%
num=[5,10,15]
num[1]=num[0]+num[2]
print(num)
print(sum(num))
# Out:
# [5, 20, 15]
# 40

# %%
marks =[50,60,70,80]
for i in range(len(marks)):
  marks[i]=marks[i]+5
print(marks)
# Out:
# [55, 65, 75, 85]

# %%
data=[2,4,6]
for i in range(len(data)):
  print(i, data[i])
# Out:
# 0 2
# 1 4
# 2 6
