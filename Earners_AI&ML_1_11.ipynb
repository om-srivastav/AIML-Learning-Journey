# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/Earners_AI%26ML_1_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Recap

# %%
a=[4,6,7,2,1]

# %%
type(a)
# Out:
# list

# %%
n=len(a)
print(n)
# Out:
# 5

# %%
for i in range(n):#iterate
  print(a[i])
# Out:
# 4
# 6
# 7
# 2
# 1

# %%
for elem in a:
  print(elem)
# Out:
# 4
# 6
# 7
# 2
# 1

# %%
#Print the elements of the list in reverse order
for i in range(n-1,-1,-1):#peak
  print(a[i])
# Out:
# 1
# 2
# 7
# 6
# 4

# %%
#m2
for i in range(n):
  print(a[n-i-1])
# Out:
# 1
# 2
# 7
# 6
# 4

# %%
num=[1,2,3,4]
n=len(num)
for i in range(n):
  num[i]=num[i]+1
print(num)
# Out:
# [2, 3, 4, 5]

# %%
marks=[65,75,85]
total=0
for m in marks:
  if m >= 70:
    total+=m
  print(total)
# Out:
# 0
# 75
# 160

# %%
nums =[2,4,6]
nums[0]=nums[2]
nums[2]=nums[1]
print(nums)
# Out:
# [6, 4, 4]

# %%
names=["amit","neha","aditya"]
longest=names[0]
for name in names:
  if len(name)>len(longest):
    longest = name
print(longest)
# it will gonna print the name with high freq char
# Out:
# aditya

# %%
data=[10,20,30]
for i in range(len(data)):
  data[i]=data[i]+10
print(max(data))
print(min(data))
# Out:
# 40
# 20

# %%
numb=[5,10,15,20]
total=0
for i in range(len(nums)):
  if i%2==0:
    total+=numb[i]
print(total)
# Out:
# 20

# %% [markdown]
# #List Slicing

# %%
a=[5,7,4,8,2,1,9]
print(a)
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
print(a[1:4])#runs till n-1
# Out:
# [7, 4, 8]

# %%
print(a[2:5])
# Out:
# [4, 8, 2]

# %%
print(a[:4])
# Out:
# [5, 7, 4, 8]

# %%
print(a[0:4])
# Out:
# [5, 7, 4, 8]

# %%
print(a[1:])
# Out:
# [7, 4, 8, 2, 1, 9]

# %%
print(a[:])
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
a
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
print(a[1:5:2])
# Out:
# [7, 8]

# %%
print(a[::2])
# Out:
# [5, 4, 2, 9]

# %% [markdown]
# #String

# %%
name="OM"

# %%
type(name)
# Out:
# str

# %%
email="omsrivastav7030@gmail.com"

# %%
#empty string:
s=""
print(s)

# %%
len(s)
# Out:
# 0

# %%
p="yoo"
len(p)
# Out:
# 3

# %%
len("omsrivastav")
# Out:
# 11

# %%
name="Om"
print(name[0])
# Out:
# O

# %%
print(name[-1])
# Out:
# m

# %%
#print the given str in reverse order

# %%
print(name[::-1])
# Out:
# mO

# %%
name="om"
n=len(name)
for i in range(n):
  print(name[n-i-1],end="")
# Out:
# mo

# %%
print(name[::])
# Out:
# om

# %%
for i in range(n):
  print(name[i])
# Out:
# o
# m

# %%
for elem in name:
  print(elem)
# Out:
# o
# m

# %%
4+6
# Out:
# 10

# %%
"4"+"6"#concatenation
# Out:
# '46'

# %%
"Om" + "Srivastav"
# Out:
# 'OmSrivastav'

# %%
word="Python"
  print("p" in word)
# Out:
# False

# %%
words="Python"
print("P"in words)
# Out:
# True

# %%
word="Python"
print("z"not in word)
# Out:
# True

# %%
word="Python"
print(word[0] + word[-1])
# Out:
# Pn

# %%
#STLD-->str,tup,list,dic
# ST-->immutable
# LD-->mutable
a=[4,7,8]
a[1]=18
print(a)
# Out:
# [4, 18, 8]

# %%
word="Code"
for i in range(len(word)):
  print(i,word[i])
# Out:
# 0 C
# 1 o
# 2 d
# 3 e

# %%
text="Python"
i=0
while i <len(text):
  print(text[i])
  i+=2
# Out:
# P
# t
# o

# %%
word="Python"
count=0
for ch in word:
  if ch in "aeiouAEIOU":
      count += 1
print(count)
# Out:
# 1

# %%
word="Python"
result=""
for ch in word:
  result = ch +result
  print(result)
# Out:
# P
# yP
# tyP
# htyP
# ohtyP
# nohtyP

# %%
text ="Data Science"
spaces=0
for ch in text:
  if ch == " ":
    spaces+=1
print(spaces)
# Out:
# 1

# %%
word="Python"
total=0
for ch in word:
  total+=1
print(total == len(word))
# Out:
# True

# %%
word="Python"
total=0
for ch in word:
  total+=1
print(total)
# Out:
# 6
