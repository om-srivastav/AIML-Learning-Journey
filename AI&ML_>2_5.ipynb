# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AI%26ML_%3E2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Recapp-- Set

# %%
s=set()
len(s)
# Out:
# 0

# %%
type(s)
# Out:
# set

# %%
s={35,5,56,6,5,5,5,5,54,3,67,7}
print(len(s))
# Out:
# 8

# %%
s.add(10)
print(s)
# Out:
# {3, 67, 35, 5, 6, 7, 10, 54, 56}

# %%
s.remove(3)
print(s)
# Out:
# {67, 35, 5, 6, 7, 10, 54, 56}

# %%
s.pop()
print(s)
# Out:
# {35, 5, 6, 7, 10, 54, 56}

# %%
s.clear()
print(s)
# Out:
# set()

# %%
3 in s
# Out:
# False

# %%
3 not in s
# Out:
# True

# %%
a=[4,5,6,6,7]
print(len(a))
# Out:
# 5

# %%
s=set(a)
print(s)
# Out:
# {4, 5, 6, 7}

# %%
s={3,3,4,4}
s2={3,4,344,4,4,}
s.union(s2)
# Out:
# {3, 4, 344}

# %%
s.intersection(s2)
# Out:
# {3, 4}

# %%
s & s2
# Out:
# {3, 4}

# %%
s |s2
# Out:
# {3, 4, 344}

# %%
s- s2
# Out:
# set()

# %%
s2-s
# Out:
# {344}

# %%
s=set("BANANA")
print(s)
# Out:
# {'A', 'B', 'N'}

# %%
words=["apple","banana","apple","mango","banana"]
unique=set(words)
result=""
for word in unique:
  result+=word[0]
print(len(result))
# Out:
# 3

# %%
text="mississippi"
letters=set(text)
count=0
for ch in letters:
  if ch in "aeiou":
    count+=1
print(count)
print(letters)
# Out:
# 1
# {'m', 'i', 's', 'p'}

# %%
colors={"Red","Green","bLUE"}
result=set()
for color in colors:
  result.add(color.upper())
print(result)
print(len(result))
# Out:
# {'BLUE', 'GREEN', 'RED'}
# 3

# %% [markdown]
# #Coding Practice

# %% [markdown]
# ## **Problem 1: Student Grade Analyzer**

# %%
# ### Problem Statement

# Write a Python program that takes marks of **5 subjects** as input.

# Your program should:

# * Store the marks in a list.
# * Calculate the average marks.
# * Find the highest and lowest marks.
# * Display the grade using the following criteria:

# | Average Marks | Grade |
# | ------------- | ----- |
# | 90+           | A     |
# | 75–89         | B     |
# | 60–74         | C     |
# | Below 60      | D     |

# %%
marks=int(input("enter your marks"))
m=[]
m.append(marks)
avg_m=(m[0]+m[1]+m[2]+m[3]+m[4])/5
highest=max(m)
lowest=min(m)
# Out:
# enter your marks66
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1643/2176125200.py in <cell line: 0>()
#       2 m=[]
#       3 m.append(marks)
# ----> 4 avg_m=(m[0]+m[1]+m[2]+m[3]+m[4])/5
#       5 highest=max(m)
#       6 lowest=min(m)
#
# IndexError: list index out of range

# %%
marks=[]
for i in range(5):
  m=int(input())
  marks.append(m)
# Out:
# 55
# 55
# 4
# 33
# 88

# %%
s= sum(marks)
n=len(marks)
avg=s/n
if avg>90:
  print("A")
elif avg>75:
  print("B")
elif avg >60:
  print("C")
else:
  print("D")
# Out:
# D

# %%
mn=min(marks)
mx=max(marks)
print(mn,mx)
# Out:
# 4 88

# %% [markdown]
# ## Problem 2: Word Frequency Counter

# %%
# ==========================================

# ==========================================

# Problem Statement:
# Take a sentence as input.
#
# Display how many times each word appears.

# %%
sentence=input()
words=sentence.split(" ")
print(words)
len(words)
# Out:
# Python is Fun
# ['Python', 'is', 'Fun']
# 3

# %%
freq={}
for word in words:
  if word not in freq:
    freq[word]=1
  else:
    freq[word]+=1
print(freq)
# Out:
# {'Python': 1, 'is': 1, 'Fun': 1}

# %% [markdown]
# #Remove duplicate names

# %%
# take names separated by spaces.
# remove duplicates names while preserving the first occurences

# %%
s=input()
names = s.split()#default delimiter is space as well
print(names)
# for names in names:
#   if names
# Out:
# om dev om amit ritesh om naman dev
# ['om', 'dev', 'om', 'amit', 'ritesh', 'om', 'naman', 'dev']

# %%
unique_names=[]
for name in names:
  if name not in unique_names:
    unique_names.append(name)
print(unique_names)
# Out:
# ['om', 'dev', 'amit', 'ritesh', 'naman']

# %%
for name in unique_names:
  print(name)
# Out:
# om
# dev
# amit
# ritesh
# naman

# %%
#m2
names=input().split()
unique=[]
for name in names:
  if name not in unique:
    unique.append(name)
for name in unique:
  print(name)
# Out:
# om dev om dev vishal
# om
# dev
# vishal

# %% [markdown]
# #P4-->Character Counter

# %%
s=input()
s1=s.lower()
vowels=0
conso=0
spaces=0
digits=0
for c in s1:
  if c in "aeiou":
    vowels+=1
  elif c>="a" and c<="z":
    conso+=1
  elif c>"0" and c<="9":
    digits+=1
  elif c==" ":
    spaces+=1
print("vowels",vowels)
print("consonants",conso)
print("spaces",spaces)
print("digits",digits)
# Out:
# hi i am om
# 4
# 3
# 3
# 0

# %%
text = input()

vowels = 0
consonants = 0
digits = 0
spaces = 0

for ch in text:
    if ch.lower() in "aeiou":
        vowels += 1
    elif ch.isalpha():
        consonants += 1
    elif ch.isdigit():
        digits += 1
    elif ch == " ":
        spaces += 1

print("Vowels :", vowels)
print("Consonants :", consonants)
print("Digits :", digits)
print("Spaces :", spaces)

# %%
"9".isalnum()
# Out:
# True

# %%
"a".isalnum()
# Out:
# True

# %% [markdown]
# #P5-->Shopping Bill

# %%
take items names and prices for 5 diff products

# %%
names=[]
prices=[]
for i in range(5):
  name=input()
  price=int(input())

  names.append(name)
  prices.append(price)
print(names)
print(prices)
# Out:
# apple
# 00
# milk
# 34
# bread
# 45
# rice
# 23
# juice
# 80
# ['apple', 'milk', 'bread', 'rice ', 'juice']
# [0, 34, 45, 23, 80]

# %%
total_bill_amt=sum(prices)
mx=prices[0]
mx_prd=""
mn =100000
for i in range(5):
  if prices[i]>mx:
    mx_prd = names[i]
    mx = prices[i]
  elif prices[i]<mn:
    mn_prd=names[i]
    mn=prices[i]
