# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AI_%26_ML_1_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Earners AI/ML by Aditya Jain Sir-LEc->12

# %% [markdown]
# #Recap

# %%
s="Aditya Jain"
type(s)
# Out:
# str

# %%
n=len(s)#space also counted
print(n)
# Out:
# 11

# %%
s[2]
# Out:
# 'i'

# %%
s[-1]
# Out:
# 'n'

# %%
a1=s[2:7]
print(a1)
# Out:
# itya

# %%
print(s[:6])#-->runs till n-1
# Out:
# Aditya

# %%
for c in s:
  print(c)
# Out:
# A
# d
# i
# t
# y
# a
#
# J
# a
# i
# n

# %%
n=len(s)
for i in range(n):
  print(s[i],end=" ")
# Out:
# A d i t y a   J a i n

# %%
a=s.split(" ")#jha jha space h vha vha se wtr got splitted
print(a)
# Out:
# ['Aditya', 'Jain']

# %%
s="om likes to do programming"
a=s.split(" ")
print(a)
# Out:
# ['om', 'likes', 'to', 'do', 'programming']

# %%
t="Programming"
c=0
for i in range(len(t)):
  if t[i]==t[-1]:
    c+=1
print(c)
# Out:
# 2

# %%
word="PYTHON"
result=""

for i in range(len(word)):
  if i%2==1:
    result += word[i]
print(result)
# Out:
# YHN

# %%
text="Data"
result=""
for ch in text:
  result= ch + result#-->ataD
  #or--> result = result +ch-->Data
print(result)
# Out:
# ataD

# %%
w="Machine"
c=0
for ch in word:
  if ch not in "aeiouAEIOU":
    c+=1
print(c)
# Out:
# 5

# %%
word="Python"
i=len(word)-1
while i>= 0:
  print(word[i],end ="")
  i -= 2
# Out:
# nhy

# %%
t="AI"
res=""
for i in range(4):
  res = res +t
print(res)
print(len(res))
# Out:
# AIAIAIAI
# 8

# %%
word="computer"
c=0
for ch in  word:
  if ch <"m":
    print(ch)
    c+=1
print(c)
# Out:
# c
# e
# 2

# %%
ord('A')#it will give the ASCII code of char
# Out:
# 65

# %%
ord('B')
# Out:
# 66

# %%
ord('c')
# Out:
# 99

# %%
ord('Z')
# Out:
# 90

# %%
chr(122)
# Out:
# 'z'

# %%
chr(128522)
# Out:
# '😊'

# %%
ord('😊')
# Out:
# 128522

# %%
word="LEVEL"
same=0
for i in range(len(word)):
  if word[i]==word[-(i+1)]:
    print(i,-(i+1),word[i],word[-(i+1)])
    same+=1
print(same)
#palindrome
# Out:
# 0 -1 L L
# 1 -2 E E
# 2 -3 V V
# 3 -4 E E
# 4 -5 L L
# 5

# %%
t="Python"
res=""
for i in range(len(t)):
  if i < len(t)//2:#-->i<3#half
    res+=t[i]
print(res)
# Out:
# Pyt

# %% [markdown]
# #Functions

# %%
print("OM")
# Out:
# OM

# %%
len("AI")
# Out:
# 2

# %%
a=2
type(a)
# Out:
# int

# %%
# def function_name():
#   #definition

# %%
#func definition
def greet():
  print("Hello")
# Out:
# Hello

# %%
greet()#-calling func to run
# Out:
# Hello

# %%
#write a func that print hello followed by  name
def yoo():

# %%
#code reusability
# function def--> Parameter
# function call --> argument

# %%
 def greet(name):
  print("Hello",name)

# %%
greet("")
# Out:
# Hello

# %%
greet("OM")
# Out:
# Hello OM

# %% [markdown]
# #Positional arg

# %%
def show(name,age):
  print("name is",name)
  print("age is",age)

# %%
show("Raj",22)
# Out:
# name is Raj
# age is 22

# %%
show("om",19)
# Out:
# name is om
# age is 19

# %%
show(20,"Priya")
# Out:
# name is 20
# age is Priya

# %% [markdown]
# #Keyworded Arg

# %%
def show(name,age):
  print("Name is",name)
  print("Age is",age)

# %%
show(age=20,name='om')
# Out:
# Name is om
# Age is 20

# %% [markdown]
# #Return Keyword

# %%
def show(a,b):
  return a+b

# %%
s=show(2,3)
print(s)
# Out:
# 5
