# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/ML_%26_AI_%3E1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EarnerAI & ML by Aditya Jain Sir--> Lecture 1.3

# %% [markdown]
# #Recap

# %%
#variables
age=20
print(age)
# Out:
# 20

# %%
# print(Age)error as python is case sensitive lang;
#print("age")-->error//It is a String...and not printing variable

# %%
#datatype
type(10)
# Out:
# int

# %%
type(5.4)
# Out:
# float

# %%
type("OM")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
#typecasting
type("4.5")
# Out:
# str

# %%
type(float("4.5"))
# Out:
# float

# %%
a=input()
# Out:
# 6

# %%
type(a)
# Out:
# str

# %%
a=int(input())
# Out:
# 12

# %%
type(a)
# Out:
# int

# %%
len=float(input())
# Out:
# 5.7

# %%
type(len)
# Out:
# float

# %%
len=input()
# Out:
# 6.7

# %%
type(len)
# Out:
# str

# %%
name="OM"
print("Hello")
print(name)
# Out:
# Hello
# OM

# %% [markdown]
# #Operators

# %%
print(5+4)
# Out:
# 9

# %%
print(4-8)
# Out:
# -4

# %%
print(10**8)
# Out:
# 100000000

# %%
print(9*7)
# Out:
# 63

# %%
print(20/5)#div-->"/"-->float_always!!
# Out:
# 4.0

# %%
print(20/6)
# Out:
# 3.3333333333333335

# %%
print(20//7)#floor-->"//"-->always_Integer
# Out:
# 2

# %%
print(20//5)
# Out:
# 4

# %%
print(20/5)
# Out:
# 4.0

# %%
# Modulus --> gives remainder --> %
print(10%3)
# Out:
# 1

# %%
print(10%6)
# Out:
# 4

# %%
print(-10%6)#sign is same as 2nd number(divisor)
print(10%-6)
# Out:
# 2
# -2

# %%
print(5%10)
# Out:
# 5

# %%
print(2%5)
# Out:
# 2

# %%
#power-->**
print(2**3)
# Out:
# 8

# %%
print(3**2)
# Out:
# 9

# %%
#calculator
num1=int(input("Enter first int "))
num2=int(input("Enter second int "))
print("The first integer is ",num1)
print("The second integer is ",num2)
print("and their-->")
print("Addition:",num1+num2)
print("Substraction:",num1-num2)
print("Multiplication:",num1*num2)
print("Division:",num1/num2)
print("Floored div:",num1//num2)
print("Modulus:",num1%num2)
print("Modulus:",num2%num1)
print("Power:",num1**num2)
# Out:
# Enter first int 10
# Enter second int 2
# The first integer is  10
# The second integer is  2
# and their-->
# Addition: 12
# Substraction: 8
# Multiplication: 20
# Division: 5.0
# Floored div: 5
# Modulus: 0
# Modulus: 2
# Power: 100

# %% [markdown]
# #Assignment Operator

# %%
x=10
print(x)
# Out:
# 10

# %%
x=10
x+=2#-->x=x+2
print(x)
# Out:
# 12

# %%
x=10
x-=4
print(x)
# Out:
# 6

# %%
c=10
c*=2
print(c)
# Out:
# 20

# %%
x=10
x/=2
print(x)
# Out:
# 5.0

# %%
x=10
x//=2
print(x)
# Out:
# 5

# %%
x=10
x**=2
print(x)
# Out:
# 100

# %% [markdown]
# #Comparison Operators

# %%
# results only in true or false//bool

# %%
10>5
# Out:
# True

# %%
10<5
# Out:
# False

# %%
10>=7
# Out:
# True

# %%
10<=4
# Out:
# False

# %%
10<=11
# Out:
# True

# %%
5<=5
# Out:
# True

# %%
5>=5
# Out:
# True

# %%
5<5
# Out:
# False

# %%
5>5
# Out:
# False

# %%
5==5#both equal or not-->5=5->no sense
# Out:
# True

# %%
2==3
# Out:
# False

# %%
5!=2 #5 not equal to 2->True
# Out:
# True

# %%
7!=7
# Out:
# False

# %% [markdown]
# #Logical Operators

# %%
# and , or and not

# %% [markdown]
# and-->tb hi true when sb true

# %%
4>3
# Out:
# True

# %%
5>3
# Out:
# True

# %%
(4>3) and (5>3)
# Out:
# True

# %%
(4>3) and (5<3)
# Out:
# False

# %%
(4<3) and (5<3)
# Out:
# False

# %% [markdown]
# or-->sb false tb hi false

# %%
(4>3) or (5<3)
# Out:
# True

# %%
(4<3) or (5>3)
# Out:
# True

# %%
(4==3) or (5>3)
# Out:
# True

# %%
(4<3) and (5==3)
# Out:
# False

# %% [markdown]
# not->reverse krna toggle krna--> true ko false;false ko true

# %%
(4>7)
# Out:
# False

# %%
not(4>7)
# Out:
# True

# %%
not((3>3) and (6<3))
# Out:
# True

# %%
not((3>3) or (6<3))
# Out:
# True

# %%
not((3>=3) or (6<3))
# Out:
# False

# %% [markdown]
# #Membership Operator

# %%
"a" in "Aditya"
# Out:
# True

# %%
"O"in "om"
# Out:
# False

# %%
"o" in "om"
# Out:
# True

# %%
"O" not in "om"
# Out:
# True

# %%
"m"not in "om"
# Out:
# False

# %%
x=6
x+=3
x*=2
print(x)
# Out:
# 18
