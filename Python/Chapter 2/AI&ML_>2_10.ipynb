# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AI%26ML_%3E2_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DPP

# %%
try:
  numbers=[5,10,15]
  index=2
  print(numbers[index])
except IndexError:
  print("Wrong Index")
else:
  print("Successful")
finally:
  print("Done")
# Out:
# 15
# Successful
# Done

# %%
try:
  age=int("Twenty")
  print(age)
except ValueError:
  print("Invalid")
finally:
  print("End")
# Out:
# Invalid
# End

# %%
try:
  student ={
      "name":"Rahul",
      "marks":90
  }
  print(student["age"])
except KeyError:
  print("Key Missing")
print("Program End")
# Out:
# Key Missing
# Program End

# %%
try:
  marks=120
  if marks>100:
    raise ValueError("Marks Invalid")
  print(marks)
except ValueError as e:
  print(e)
print("Completed")
# Out:
# Marks Invalid
# Completed

# %%
# total=0
# for student in students:
#   print(student["marks"]))
#   total+=student["marks"]
# print(total)

# %%
def calc_grade(marks):
  if marks>90:
    grade="A"
  elif marks >75:
    grade="B"
  elif marks >60:
    grade="C"
  else:
    grade="D"
  return grade

# %%
# for student in students:
  # print(student["marks"],calc_grade(student["marks"]))

# %%
def search(roll_no):
  found=False
  for student in students:
    if student["roll"]==roll_no:
      print(student)
      found=True
      break
  return found

# %%
roll=int(input())
ans= search(roll)
print(ans)
# Out:
# 88
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3655/3220972723.py in <cell line: 0>()
#       1 roll=int(input())
# ----> 2 ans= search(roll)
#       3 print(ans)
#
# /tmp/ipykernel_3655/532051267.py in search(roll_no)
#       1 def search(roll_no):
#       2   found=False
# ----> 3   for student in students:
#       4     if student["roll"]==roll_no:
#       5       print(student)
#
# NameError: name 'students' is not defined

# %%
# def find_topper(students):
#   for student in students:
#     if student["marks"]>mx_marks:
#       mx_marks =  student["marks"]

# %%
# name = input("enter")
# for student in students:
#   if student["name"].lower() == name.lower():
#     print(student)

# %%
courses={}
for student in students:
  if student["course"] not in courses:
    courses[student["courses"]]=1
  else:
    courses[student["courses"]]+=2
  print(courses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3655/3168739322.py in <cell line: 0>()
#       1 courses={}
# ----> 2 for student in students:
#       3   if student["course"] not in courses:
#       4     courses[student["courses"]]=1
#       5   else:
#
# NameError: name 'students' is not defined

# %%
# create student class(oop) in the above format

# %%
class Student:

 def __init__(self,roll,name,age,course,marks):
   self.roll=roll
   self.name=name
   self.age=age
   self.course=course
   self.marks=marks
def show_student(self):
  print(self.roll,self.age,self.course,self.marks)

# %%
s1= Student(106,"MJ",30,"Dance",100)

# %%
while True:
  choice=int(input("enter"))
if choice == 2:
  for student in students:
    print(student)
elif choice == 3:
  name = input("enter student name:")
  search_student(name)
elif choice == 4:
  print_topper()
elif choice==5:
  total =0
  for student in students:
    total+=student["marks"]
  print("Average", total/len(students))
elif choice == 6:
  print("ThankYOu")
else:
  print("Invalid")
  break
# Out:
# enter2
# enter2
# enter2
# enter2
# enter2
# enter2
# enter2
# enter2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3655/3380546862.py in <cell line: 0>()
#       1 while True:
# ----> 2   choice=int(input("enter"))
#       3 if choice == 2:
#       4   for student in students:
#       5     print(student)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
2
2
2
2
2
