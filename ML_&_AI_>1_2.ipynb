# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/ML_%26_AI_%3E1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A", "B", "C")
# Out:
# A B C

# %% [markdown]
# #**Comments**

# %%
#This code prints OM on the screen.
print("OM")
# Out:
# OM

# %%
# By pressing (ctrl + /) you can comment out any text.
#   For Multi Line comments-->
# select all lines then ctrl+/
# by ctrl + / you can comment or decomment the text

# %%
# print("Hello")
print("Python")
# Out:
# Python

# %% [markdown]
# #**Variables**

# %%
name="Om"
city="Deoria"
id=2511723

# %%
print(name)
# Out:
# Om

# %%
print(id)
# Out:
# 2511723

# %%
print(city)
# Out:
# Deoria

# %%
#Variable naming rule
# 1.Start: Alphabet + _
# 2. Middle or end --> Alphabet, _ ,digits

# %%
# student_name --> valid
# _marks --> valid
# City --> valid
# State5 --> valid
# 4city --> invalid
# student-name -> invalid

# %%
#  variable_name = value

# %%
name="OM"
city="nagpur"
state="up"
id=24
print(name)
print(city)
print(state)
print(id)
# Out:
# OM
# nagpur
# up
# 24

# %%
#  first name ="OM"-->invalid variable

# firstName-->camelCase
# first_name-->also-correct

# %%
college = "PSIT"
print(college)
college = "IIT Bombay"
print(college)
# Out:
# PSIT
# IIT Bombay

# %% [markdown]
# #Data Types

# %%
# 5# 1. Integer --> int
#  eg: 522,2511723
# #2. Double or Float --> decimal
#  eg: 2.0,4,-7,0,7,0.5,2.0,-6.7
# # #3. String (text data)--> str
# eg:  "Aditya","Nagpur","OM"
# # 4. Boolean -- True/False-->bool
# Out:
#   File "/tmp/ipykernel_12031/2237553381.py", line 2
#     eg: 50,4,-7,0,22,2511723
#     ^
# IndentationError: unexpected indent

# %%
"4" -->str
5-->int
5.0-->float
True --> bool

# %%
#by using type keyword u can know the datatype

# %%
type(4)

# %%
type("TRUE")

# %%
type(True)

# %%
hello=False
type(hello)

# %%
type("5.7")

# %% [markdown]
# #Taking input from the user

# %%
name=input()

# %%
print(name)

# %%
#input()-->by defaut str dt
name=input("enter your name")

# %%
print(name)
# Out:
# OM

# %%
#today_task
#take two int as input from the user and print their sum
num1=int(input("enter num1 "))
num2=int(input("enter num2 "))
sum=num1+num2
print("sum of num1 & num2 is-->",6sum)
# Out:
# enter num1 66
# enter num2 6
# sum of num1 & num2 is--> 72

# %%
#str concatenation
# "4"+"4"-->44
#or-->
num1=input()#-->str
num2=input()#-->str
sum=num1+num2
print(sum)
# Out:
# 9
# 9
# 99

# %%
#we can typecast str to int by forcefully writing int at the suffix
# like-->
age='28'
newAge=int(age)
type(newAge)
# Out:
# int

# %%
type(age)
# Out:
# str

# %%
a=input()
b=input()
c=int(a)+int(b)#typecasting-->changing dt
print(c)
# Out:
# 4
# 4
# 8

# %%
#mentos zindagi-->mujhe phle se aata tha vaise
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
# 5
# 4
# 9

# %%
#take year of birth as input and print the age
birth_year=int(input("enter your birth year "))
present_year=int(input("enter present year "))
age=present_year-birth_year
print("your age is-->",age)
if age>=18 :
  print("eligible to drive a car")
else:
    print("can't drive")
# Out:
# enter your birth year 2009
# enter present year 2026
# your age is--> 17
# can't drive

# %%
#take length and breadth as input and print rec area
l=float(input("enter length "))
b=float(input("enter breadth "))
area=l*b
print("area of rec is-->",area)
# Out:
# enter length 88
# enter breadth 9
# area of rec is--> 792.0

# %%
#take name,age and height of student as input and print them
name=input("enter your name ")
age=int(input("enter your age "))
height=float(input("enter your height in inches "))
print("-----------------")
print(name,age,height)
# Out:
# enter your name om
# enter your age 17
# enter your height in inches 70.8
# -----------------
# om 17 70.8

# %%
# variable-->container for storing data
# only type-->dt
# printing using type keyword-->class-dt
# eg:
yoo = True
type(yoo)
# print(type(yoo))
# Out:
# bool
