# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AIML_Earners_1_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Earners AI ML - by Aditya Jain Sir- Lecture-1.7

# %% [markdown]
# #Recap = for loop :Quiz

# %%
for i in range(5):
  print("Hello")#5 times run

# %%
for i in range(4):
  print(i)

# %%
for i in range(3,8):
  print(i,end=" ")

# %%
for i in range(2,11,2):
  print(i)

# %%
for i in range(10,0,-2):
  print(i)

# %%
for i in range(5):
  print(i)

# %%
for i in range(1,6):
  print(i*i)

# %%
for ch in "Python":
  # print(ch)
  print(ch,end="")

# %%
for i in range(5,1,-1):
  print(i)

# %%
for i in range(1,10,3):
  print(i)

# %%
for i in range(1,11,2):
  print(i)

# %%
for i in range(3,3):
  print(i)#nothing gonna print

# %%
for i in range(4):
  print(i+10)

# %%
for i in range(2):
  print("Python")
  print("AI")

# %%
for i in range(2):
  print("Python")
print("AI")

# %%
name="Data"
for ch in name:
  if ch == "a":
    print(ch)

# %% [markdown]
# #While loop

# %%
# 1.initialization
# 2.condition
# 3.updation

# %%
# Print all in from 1 to 5
for i in range(1,6):
  print(i)

# %%
i = 1
while(i<6):
  print(i)
  i=i+1

# %%
# Write a while loop to print 7 times on the screen.
i=1
while(i<=7):
  print("Hi")
  i=i+1

# %%
# Write a while loop to print 7 times on the screen.
i=1
while i<=7:
  print(i,"Hi")
  i+=1

# %%
i=7
while i>=1:
  print(i,'HI')
  i-=1

# %%
i=0
while i<=10:
  print(i)
  i+=2

# %%
i=0
while i<=10:
  if i%2==0:
   print(i)
  i+=1

# %%
i=1
while i<10:
  print(i)
  i+=2

# %%
# print sum of all numbers b/w 1 to 10
sum=0
for i in range(1,11):
  sum+=i
  print(sum)

# %%
n=10,10*11/2=55

# %%
sum=0
i=1
while i<=10:
  sum+=i
  i+=1

print(sum) #55

# %%
# print multiplication table of 5 by while loop
i=1
while i<=10:
  print("5 *",i,"=",i*5)
   i+=1
