# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AI%26ML_%3E2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Earners AI&ML by aditya JAIN-->LEC2.3

# %% [markdown]
# #Recap-->Tuple

# %%
a=(1,2,4,4)

# %%
type(a)
# Out:
# tuple

# %%
len(a)
# Out:
# 4

# %%
a[2]
# Out:
# 4

# %%
n=len(a)
for i in range(n):
  print(a[i])
# Out:
# 1
# 2
# 4
# 4

# %%
for elem in a:
  print(elem)
# Out:
# 1
# 2
# 4
# 4

# %%
a=("Raj",34)
name, age=a
print(name)
print(age)
# Out:
# Raj
# 34

# %%
type(a)
# Out:
# tuple

# %% [markdown]
# #HW

# %%
values=(5,4,4,4)
total=0
for value in values:
  if value%5==0:
    total+=value
print(total)
# Out:
# 5

# %%
colors=("red","blu","ff")
for color in colors:
  print(color[0], end="")
print()
# Out:
# rbf

# %%
num=(1,2,3)
a,b,c =num
print(a+b*c)
# Out:
# 7

# %%
marks=(80,90,95)
bonus=()
for mark in marks:
  bonus+=(mark+5,)
print(bonus)
# Out:
# (85, 95, 100)

# %%
fruits=("appple","mango","banana")
for fruit in fruits:
  if "a"in fruit.lower():
    print(fruit)
# Out:
# appple
# mango
# banana

# %%
"Aditya".lower()
# Out:
# 'aditya'

# %%
"Aditya".upper()
# Out:
# 'ADITYA'

# %%
"aditya".title()
# Out:
# 'Aditya'

# %%
fruits=("apple","Banana","Mango")
for fruit in fruits:
  if "a" in fruit:
      print(fruit)
# Out:
# apple
# Banana
# Mango

# %%
prices=(100,200,222)
discount=()
for p in prices:
  discount+=(p-20,)
  print(sum(discount))
# Out:
# 80
# 260
# 462

# %%
(2,3)*8
# Out:
# (2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3)

# %%
[3,4,4]*3
# Out:
# [3, 4, 4, 3, 4, 4, 3, 4, 4]

# %%
data=(2,4,5,6)
count=0
for num in data:

    if num %4==0:
      count+=1
print(count)
# Out:
# 1

# %% [markdown]
# DPP- Module 1 Challenge

# %%
nums=[10,15,20,25]
result=()
for num in  nums:
  if num%10==0:
    result+=(num//2,)
print(result)
print(sum(result))
# Out:
# (5, 10)
# 15

# %%
text="Programming"
c=0
for ch in text:
  if ch.lower() in "aeiou":
    c+=1
print(c)
# Out:
# 3

# %%
stu={
    "math":90,
    "sci":80,
    "eng":96
}
total=0
for sub in stu:
  if stu[sub]>85:
    total+=stu[sub]
print(total)
# Out:
# 186

# %%
#Given a str, write a convert it to lowercase,without using lowercase() func
s="Raj"
#just add 32 to any ascii code to convert in lowercase
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1861/1720212944.py in <cell line: 0>()
#       1 #Given a str, write a convert it to lowercase,without using lowercase() func
#       2
# ----> 3 'C'-'A'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
ord('C')-ord('A')
# Out:
# 2

# %%
print(ord("A"), ord("a"))
ord("a")-ord("A")
# Out:
# 65 97
# 32

# %%
s="Raj"
new_s=""
for ch in s:
  if  ch<='Z' and ch>='A':
     new_s+=chr(ord(ch)+32)

print(new_s)
# Out:
# r

# %%
s="Raj"
new_s=""
for ch in s:
  if ch <='z' and ch>='a':
    new_s+= chr(ord(ch)-32)
  else:
    new_s +=ch

  print(new_s)
# Out:
# R
# RA
# RAJ

# %%
print(ord("A"),ord("a"))
# Out:
# 65 97

# %%
marks=[80,90,75]
def avg(data):
  return sum(data)/len(data)
print(avg(marks))
# Out:
# 81.66666666666667

# %%
names=["Amit","Rahul","Riya","Neha"]
largest=""
for name in names:
  if len(name) > len(largest):
    largest=name
print(largest)
# Out:
# Rahul

# %%
text="banana"
count={}
for ch in text:
  if ch not in count:
    count[ch]=1
  else:
    count[ch]+=1
print(count["a"])
# Out:
# 3
