# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AI_%26_ML_%3E2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Earners AIML by Aditya Jain sir->Lec 2.4

# %% [markdown]
# DPP Ques

# %%
def fun(values):
  t=0
  for v in values:
    if v % 2==0:
      t+=v
  return t
num=[5,8,12,7,10]
print(fun(num))
# Out:
# 30

# %%
stu={
    "math":80 ,
    "sci":90,
    "eng":88
}
c=0
for sub in stu:
  if stu[sub]>=85:
    c+=1
print(c)
# Out:
# 2

# %%
stu={
    "math":80,
    "sci":90,
    "eng":85
}
sub=[]
for  v in stu:
  if stu[v]>=85:
    sub.append(v)

print(sub)
# Out:
# ['sci', 'eng']

# %%
values={2,4,6,8}
total=0
for value in values:
  total+=value
print(total//len(values))
# Out:
# 5

# %%
num=[3,6,9]
new=[]
for n in num:
  new.append(n*n)
print(max(new))
# Out:
# 81

# %%
student=("Rahul",22,95)
name,age,marks=student
if marks>90:
  grade="A"
else:
  grade="B"
print(name,grade)
# Out:
# Rahul A

# %%
text="Mississippi"
count={}
for ch in text:
  if ch not in count:
    count[ch]=1
  else:
    count[ch]+=1
print(count["s"])
# Out:
# 4

# %%
words=["cat","elephant","dog","tiger"]
longest=words[0]
for word in words:
  if len(word)>len(longest):
    longest=word
print(longest)
# Out:
# elephant

# %% [markdown]
# #SET

# %%
# an unordered collection of distinct elements
# unordered ,unique elem
#mutable(add/remove elements)
#set is not subscriptable-->as it doesn't allow accessing via indexing

# %%
nums={3,4,5,6,6}
type(num)
# Out:
# set

# %%
fruits ={"apple","banana","orange"}

# %%
num={3,3,3,3,3,33,3}
len(num)
# Out:
# 2

# %%
num={3,3,3,3,3,3,3,3}
len(num)
# Out:
# 1

# %%
type(num)
# Out:
# set

# %%
l=[]
t=()
d={}#empty dict
s=set()

# %%
len(s)
# Out:
# 0

# %%
num.add(100)
print(n)
# Out:
# 3

# %%
for n in num:
  print(n)
# Out:
# 3
# 100

# %%
num.add(10)
print(num)
# Out:
# {10, 3, 100}

# %%
print(num)
# Out:
# {10, 3, 100}

# %%
num.clear()

# %%
#write a code to stor wonly unique occurences means distinct
students={
    "rahul",
    "amit",
    "priya",
    "pragya",
    "om"

}
s1=[]
for elem in students:
  if elem not in s1:
    s1.append(elem)
print(s1)
# Out:
# ['priya', 'om', 'rahul', 'pragya', 'amit']

# %%
s={4,5.5,"OM",False}
print(type(s))
# Out:
# <class 'set'>

# %%
nums={4,4,4,4,5,6,}
nums.remove(6)
print(nums)
# Out:
# {4, 5}

# %%
print(nums)
# Out:
# {4, 5}

# %%
item=nums.pop()#-->it will remove random any elem
print(nums)
# Out:
# {5}

# %%
nums.clear()
print(nums)
# Out:
# set()

# %%
#union
A={1,2,3}
B={3,4,5}
print(A | B)
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersection
A={1,2,3}
B={3,4,5}
print(A & B)
# Out:
# {3}

# %%
print(A-B)#set diff
# Out:
# {1, 2}

# %%
#
