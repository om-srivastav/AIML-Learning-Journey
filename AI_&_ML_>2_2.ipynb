# %% [markdown]
# <a href="https://colab.research.google.com/github/om-srivastav/AIML-Learning-Journey/blob/main/AI_%26_ML_%3E2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Earners AI/ML By Aditya Jain Sir - Lecture 2.2

# %%
student= {
    "name":"raj",
    "marks": 95,
    "city":"Deoria"
}

# %%
type(student)
# Out:
# dict

# %%
print(student)
# Out:
# {'name': 'raj', 'marks': 95, 'city': 'Deoria'}

# %%
student["name"]
# Out:
# 'raj'

# %%
student["city"]
# Out:
# 'Deoria'

# %%
student["marks"]
# Out:
# 95

# %%
student.get("city")
# Out:
# 'Deoria'

# %%
student.get(0)

# %%
student.get("state", " not found")
# Out:
# ' not found'

# %%
for k in student:
  print(k)
# Out:
# name
# marks
# city

# %%
for k in student.keys():
  print(k)
# Out:
# name
# marks
# city

# %%
for v in student.values():
  print(v)
# Out:
# raj
# 95
# Deoria

# %%
for k in student.keys():
  print(k)
# Out:
# name
# marks
# city

# %%
for item in student.items():
  print(item)
# Out:
# ('name', 'raj')
# ('marks', 95)
# ('city', 'Deoria')

# %%
fruit ={
    "apple" : 50,
    "banana": 20
}
fruit["apple"]+= fruit["banana"]

# %%
stu = {
    "math": 90,
    "science":85,
    "english":98,
}
highest=0
for subject in stu:
  if stu[subject] > highest:
    highest = stu[subject]
print(highest)
# Out:
# 98

# %%
stu = {
    "name":"om", "age":20
}
stu["age"]=stu["age"]+len(stu)
print(stu["age"])
# Out:
# 22

# %%
data={}


data["A"]=10
data["B"]=20
data["A"]=30

print(len(data))
# Out:
# 2

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 2

# %%
data = {}

data["A"] = 10
data["B"] =20
data["A"] = 30
print(len(data))
# Out:
# 2

# %%
stu={
    "math":80,
    "science":90,
    "english":99
}
count =0;

for key in stu:
  if stu[key]>= 87:
    count+=1
print(count)
# Out:
# 2

# %%
person={
    "name":"amit",
    "age": 25
}
person.pop("age")
person["age"]=30
print(person)
# Out:
# {'name': 'amit', 'age': 30}

# %%
marks={
    "math":90,
    "science":80,
    "english":70
}
total = 0
for subject in marks:
  if marks[subject] >= 80:
    total += marks[subject]
print(total)
# Out:
# 170

# %%
stu={
    "math":90,
    "sci":90
}
stu["Total"]=0
for key in
# Out:
#   File "/tmp/ipykernel_1186/75440804.py", line 6
#     for key in
#               ^
# SyntaxError: invalid syntax

# %%
student={
    "math":90,
    "science":80
}
student["Total"]=0

for key in student:
  if key!= "total":
    student["Total"]+=student[key]
print(student["Total"])
# Out:
# 340

# %% [markdown]
# #Tuple

# %%
days=("monday","tuesday","wednesday","thursday","friday","saturday")
print(days)
# Out:
# ('monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday')

# %%
a=("aj",9.9,24,True)
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 24

# %%
emp=()
len(emp)
# Out:
# 0

# %%
type(emp)
# Out:
# tuple

# %%
c=(1)
type(c)
# Out:
# int

# %%
d=(1,)
print(d)
# Out:
# (1,)

# %%
44
# Out:
# 44

# %%
a
# Out:
# ('aj', 9.9, 24, True)

# %%
print(a[1])
# Out:
# 9.9

# %%
print(a[-1])
# Out:
# True

# %% [markdown]
# #Traversing the Tuple

# %%
for elem in a:
  print(elem)
# Out:
# aj
# 9.9
# 24
# True

# %%
n=len(a)
for i in range(n):
  print(a[i])
# Out:
# aj
# 9.9
# 24
# True

# %%
print(a[1:3])
# Out:
# (9.9, 24)

# %%
num=(2,3,4)
print(sum(num))
# Out:
# 9

# %%
print(num.count(4))
# Out:
# 1

# %%
num.index(4)
# Out:
# 2

# %% [markdown]
# #Packing and Unpacking

# %%
stu=("raj",9.9,24)

# %%
type(stu)
# Out:
# tuple

# %%
#Unpacking
name, cgpa , age=stu

# %%
print(name)
# Out:
# raj

# %%
name, cgpa, age=("raj",9.9,34)
print(name,age)
# Out:
# raj 34

# %%
def show():
  return 2,4

# %%
a=show()
print(a)
# Out:
# (2, 4)
